# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sqlalchemy import create_engine

pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", lambda value: f"{value:,.4f}")

sns.set_theme(style="whitegrid")

# %%
DATABASE_URL = (
    "postgresql+psycopg2://"
    "finpulse_user:finpulse_password"
    "@postgres:5432/finpulse"
)

engine = create_engine(DATABASE_URL)

query = """
SELECT *
FROM staging.stg_bank_churners
ORDER BY customer_id
"""

df = pd.read_sql(query, engine)

print(f"Linhas: {df.shape[0]:,}")
print(f"Colunas: {df.shape[1]}")
display(df.head())
# Out:
# Linhas: 10,127
# Colunas: 22
#    customer_id   attrition_status  churn_flag  customer_age gender  \
# 0    708082083  Existing Customer           0            45      F
# 1    708083283  Attrited Customer           1            58      M
# 2    708084558  Attrited Customer           1            46      M
# 3    708085458  Existing Customer           0            34      F
# 4    708086958  Existing Customer           0            49      F
#
#    dependent_count education_level marital_status income_category  \
# 0                3     High School        Married  Less than $40K
# 1                0         Unknown         Single     $40K - $60K
# 2                3       Doctorate       Divorced    $80K - $120K
# 3                2      Uneducated         Single  Less than $40K
# 4                2      Uneducated        Married         Unknown
#
#   card_category  months_on_book  total_relationship_count  \
# 0          Blue              36                         4
# 1          Blue              45                         3
# 2          Blue              38                         6
# 3          Blue              24                         6
# 4          Blue              41                         3
#
#    months_inactive_last_12m  contacts_count_last_12m  credit_limit  \
# 0                         3                        3    3,544.0000
# 1                         1                        3    3,421.0000
# 2                         3                        3    8,258.0000
# 3                         2                        2    1,438.3000
# 4                         5                        2    3,128.0000
#
#    total_revolving_balance  average_open_to_buy  amount_change_q4_q1  \
# 0               1,661.0000           1,883.0000               0.8310
# 1               2,517.0000             904.0000               0.9920
# 2               1,771.0000           6,487.0000               0.0000
# 3                   0.0000           1,438.3000               0.8270
# 4                 749.0000           2,379.0000               0.5980
#
#    total_transaction_amount  total_transaction_count  \
# 0               15,149.0000                      111
# 1                  992.0000                       21
# 2                1,447.0000                       23
# 3                3,940.0000                       82
# 4                4,369.0000                       59
#
#    transaction_count_change_q4_q1  average_utilization_ratio
# 0                          0.7340                     0.4690
# 1                          0.4000                     0.7360
# 2                          0.0000                     0.2140
# 3                          0.9520                     0.0000
# 4                          0.7350                     0.2390
